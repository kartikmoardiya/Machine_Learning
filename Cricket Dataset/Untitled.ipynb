# %%
import pandas as pd

# %%
deliveries = pd.read_csv('deliveries.csv')
matches = pd.read_csv('matches.csv')

# %%
deliveries.head( )
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
deliveries.shape
# Out:
# (179078, 21)

# %%
import seaborn as sns

# %%
sns.heatmap(pd.crosstab(deliveries['batting_team'],deliveries['bowling_team']))
# Out:
# <Axes: xlabel='bowling_team', ylabel='batting_team'>

# %%
SRHvsCSK = deliveries[deliveries['batting_team'] == 'Sunrisers Hyderabad' ]
SRHvsCSK
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 178462     11413       1  Sunrisers Hyderabad               Delhi Capitals
# 178463     11413       1  Sunrisers Hyderabad               Delhi Capitals
# 178464     11413       1  Sunrisers Hyderabad               Delhi Capitals
# 178465     11413       1  Sunrisers Hyderabad               Delhi Capitals
# 178466     11413       1  Sunrisers Hyderabad               Delhi Capitals
#
# ...

# %%
SRHvsCSK[SRHvsCSK['bowling_team'] == 'Chennai Super Kings']
# Out:
#         match_id  inning         batting_team         bowling_team  over  \
# 97960        414       1  Sunrisers Hyderabad  Chennai Super Kings     1
# 97961        414       1  Sunrisers Hyderabad  Chennai Super Kings     1
# 97962        414       1  Sunrisers Hyderabad  Chennai Super Kings     1
# 97963        414       1  Sunrisers Hyderabad  Chennai Super Kings     1
# 97964        414       1  Sunrisers Hyderabad  Chennai Super Kings     1
# ...          ...     ...                  ...                  ...   ...
# 174568     11332       1  Sunrisers Hyderabad  Chennai Super Kings    20
# 174569     11332       1  Sunrisers Hyderabad  Chennai Super Kings    20
# 174570     11332       1  Sunrisers Hyderabad  Chennai Super Kings    20
# 174571     11332       1  Sunrisers Hyderabad  Chennai Super Kings    20
# 174572     11332       1  Sunrisers Hyderabad  Chennai Super Kings    20
#
#         ball    batsman non_striker     bowler  is_super_over  ...  bye_runs  \
# ...

# %%
SRHvsCSK['over'].value_counts()
# Out:
# over
# 1     690
# 2     681
# 3     674
# 6     669
# 5     664
# 4     661
# 7     661
# 9     660
# 10    660
# 8     658
# 12    653
# 11    651
# 14    650
# 13    648
# 15    646
# 16    638
# 17    627
# 18    618
# 19    584
# 20    515
# Name: count, dtype: int64

# %%
SRHvsCSK[SRHvsCSK['batsman'] == 'Q de Kock'][SRHvsCSK['bowler'] == 'MM Sharma'][SRHvsCSK['player_dismissed'] == 'Q de Kock']
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_21128\1061785696.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   SRHvsCSK[SRHvsCSK['batsman'] == 'Q de Kock'][SRHvsCSK['bowler'] == 'MM Sharma'][SRHvsCSK['player_dismissed'] == 'Q de Kock']
# C:\Users\Asus\AppData\Local\Temp\ipykernel_21128\1061785696.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   SRHvsCSK[SRHvsCSK['batsman'] == 'Q de Kock'][SRHvsCSK['bowler'] == 'MM Sharma'][SRHvsCSK['player_dismissed'] == 'Q de Kock']
#        match_id  inning         batting_team         bowling_team  over  ball  \
# 97962       414       1  Sunrisers Hyderabad  Chennai Super Kings     1     3
#
#          batsman non_striker     bowler  is_super_over  ...  bye_runs  \
# 97962  Q de Kock    S Dhawan  MM Sharma              0  ...         0
#
#        legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
SRHvsCSK['batsman'].unique
# Out:
# <bound method Series.unique of 0             DA Warner
# 1             DA Warner
# 2             DA Warner
# 3             DA Warner
# 4             DA Warner
#               ...
# 178462    Mohammad Nabi
# 178463    Mohammad Nabi
# 178464         DJ Hooda
# 178465      Rashid Khan
# 178466     Basil Thampi
# Name: batsman, Length: 12908, dtype: object>
